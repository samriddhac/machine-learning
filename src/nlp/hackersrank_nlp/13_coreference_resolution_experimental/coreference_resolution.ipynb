# %%
import nltk
from nltk.corpus import brown
from nltk import pos_tag

# %%
sents = brown.tagged_sents(categories=['fiction'])

# %%
sents[:10]
# Out:
# [[('Thirty-three', 'CD-HL')],
#  [('Scotty', 'NP'),
#   ('did', 'DOD'),
#   ('not', '*'),
#   ('go', 'VB'),
#   ('back', 'RB'),
#   ('to', 'IN'),
#   ('school', 'NN'),
#   ('.', '.')],
#  [('His', 'PP$'),
#   ('parents', 'NNS'),
#   ('talked', 'VBD'),
#   ('seriously', 'RB'),
#   ('and', 'CC'),
#   ('lengthily', 'RB'),
#   ('to', 'IN'),
#   ('their', 'PP$'),
#   ('own', 'JJ'),
#   ('doctor', 'NN'),
#   ('and', 'CC'),
#   ('to', 'IN'),
#   ('a', 'AT'),
#   ('specialist', 'NN'),
#   ('at', 'IN'),
#   ('the', 'AT'),
#   ('University', 'NN-TL'),
#   ('Hospital', 'NN-TL'),
#   ('--', '--'),
#   ('Mr.', 'NP'),
#   ('McKinley', 'NP'),
#   ('was', 'BEDZ'),
#   ('entitled', 'VBN'),
#   ('to', 'IN'),
#   ('a', 'AT'),
#   ('discount', 'NN'),
#   ('for', 'IN'),
#   ('members', 'NNS'),
#   ('of', 'IN'),
#   ('his', 'PP$'),
#   ('family', 'NN'),
#   ('--', '--'),
#   ('and', 'CC'),
#   ('it', 'PPS'),
#   ('was', 'BEDZ'),
#   ('decided', 'VBN'),
#   ('it', 'PPS'),
#   ('would', 'MD'),
# ...
